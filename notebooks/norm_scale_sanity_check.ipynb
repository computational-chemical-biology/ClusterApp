# %% [markdown]
# ## Step by step api's methods description

# %%
import os
import re
import pandas as pd
import numpy as np
import qiime2
from qiime2 import Artifact
from qiime2.plugins import metadata, feature_table, diversity, emperor
from q2_emperor import plot, procrustes_plot, biplot, generic_plot
from scipy.spatial.distance import squareform, pdist
import skbio

# %%
# !ls ..
# Out:
# Dockerfile  README.md	 api		     notebooks
# Makefile    __pycache__  docker-compose.yml  run_server.sh

# %%
# !pwd
# Out:
# /ClusterApp/notebooks

# %%
# Change directory to import function from api
os.chdir('..')

# %%
os.getcwd()
# Out:
# '/ClusterApp'

# %%
os.listdir('api/src/service/factorys')
# Out:
# ['NormalizationFactory.py', 'ScalingFactory.py', '__init__.py', '__pycache__']

# %%
#from api.utils import qiime2PCoA
from api.src.service.gnps import Proteosafe

# %%
taskid = 'a0b4377f6e4540268602c30fedf69b0b'
# Can you see the available options in the code? We have to create a 
# drop-down menu for the user to choose
workflow = 'FBMN'
metric = 'euclidean'
gnps_result = Proteosafe(taskid, workflow)
gnps_result.get_gnps()

# %%
gnps_result.meta.head()
# Out:
#                           filename  ATTRIBUTE_Sample_Number  \
# 0  10_3uL_30_05_1-33_01_3004.mzXML                       10
# 1  11_3uL_01_06_1-42_01_3131.mzXML                       11
# 2  12_3uL_30_05_1-68_01_3052.mzXML                       12
# 3  78_3uL_03_07_1-66_01_3757.mzXML                       78
# 4  79_3uL_03_07_1-17_01_3699.mzXML                       79
#
#    ATTRIBUTE_Order_Injection_2965_3788 ATTRIBUTE_Plot ATTRIBUTE_Forest_Region  \
# 0                                 3004              T               Secondary
# 1                                 3131              T               Secondary
# 2                                 3052              T               Secondary
# 3                                 3757              K                 Primary
# 4                                 3699              K                 Primary
#
#   ATTRIBUTE_Pertubation ATTRIBUTE_Super_Order_APGIV_Clade  \
# 0              Clearcut                          Monocots
# 1              Clearcut                          Monocots
# 2              Clearcut                          Monocots
# 3             Preserved                          Monocots
# 4             Preserved                          Monocots
#
#   ATTRIBUTE_Order_APGIV_Order ATTRIBUTE_Family ATTRIBUTE_Genus  ...  \
# 0                    Arecales        Arecaceae         Euterpe  ...
# 1                    Arecales        Arecaceae         Euterpe  ...
# 2                    Arecales        Arecaceae         Euterpe  ...
# 3                    Arecales        Arecaceae         Euterpe  ...
# 4                    Arecales        Arecaceae         Euterpe  ...
#
#   ATTRIBUTE_Order_APGIII ATTRIBUTE_CS  ATTRIBUTE_AB  ATTRIBUTE_LIG  \
# 0                  0.105        0.135         0.016          0.387
# 1                  0.105        0.135         0.016          0.387
# 2                  0.105        0.135         0.016          0.387
# 3                  0.116        0.211         0.010          0.347
# 4                  0.116        0.211         0.010          0.347
#
#    ATTRIBUTE_AFE  ATTRIBUTE_CMSF  ATTRIBUTE_Asat  ATTRIBUTE_C  ATTRIBUTE_N  \
# 0          0.120         456.674          32.262       14.155          NaN
# 1          0.120         456.674          32.262       14.155          NaN
# 2          0.120         456.674          32.262       14.155          NaN
# 3          0.064         484.183          23.933       20.231          NaN
# 4          0.064         484.183          23.933       20.231          NaN
#
#    ATTRIBUTE_C/N
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 22 columns]

# %%
gnps_result.feat.head()
# Out:
#    row ID     row m/z  row retention time  \
# 0       5  353.265401           35.119569
# 1       7  381.296298           37.262528
# 2       8  581.148154            7.884651
# 3      10  609.268397           35.247439
# 4      13  305.156498           49.782424
#
#    12_3uL_30_05_1-68_01_3052.mzXML Peak area  \
# 0                               1.099282e+06
# 1                               9.998174e+05
# 2                               1.348523e+06
# 3                               5.505347e+05
# 4                               6.643086e+05
#
#    78_3uL_03_07_1-66_01_3757.mzXML Peak area  \
# 0                                1631616.110
# 1                                1445426.520
# 2                                1536205.639
# 3                                1259964.695
# 4                                 299720.325
#
#    11_3uL_01_06_1-42_01_3131.mzXML Peak area  \
# 0                               1.281668e+06
# 1                               1.249140e+06
# 2                               5.228738e+06
# 3                               1.099087e+06
# 4                               8.127709e+05
#
#    10_3uL_30_05_1-33_01_3004.mzXML Peak area  \
# 0                                 860049.175
# 1                                 915588.990
# 2                                1779064.237
# 3                                1900706.545
# 4                                 559341.440
#
#    80_3uL_30_05_1-58_01_3033.mzXML Peak area  \
# 0                                1254956.950
# 1                                1234167.890
# 2                                 127515.698
# 3                                 525107.070
# 4                                 714114.810
#
#    153_3uL_01_06_1-23_01_3111.mzXML Peak area  \
# 0                                1.010253e+06
# 1                                9.921647e+05
# 2                                1.108239e+05
# 3                                4.631662e+05
# 4                                9.085950e+05
#
#    152_3uL_01_06_1-87_01_3074.mzXML Peak area  \
# 0                                  900838.985
# 1                                  800190.520
# 2                                   36034.871
# 3                                  325802.580
# 4                                  683273.360
#
#    79_3uL_03_07_1-17_01_3699.mzXML Peak area  \
# 0                               1.441528e+06
# 1                               1.270731e+06
# 2                               2.423437e+04
# 3                               3.167505e+05
# 4                               4.172964e+05
#
#    224_3uL_03_07_1-81_01_3774.mzXML Peak area  \
# 0                                1.391126e+06
# 1                                1.384528e+06
# 2                                1.746068e+06
# 3                                3.375690e+06
# 4                                3.073419e+05
#
#    154_3uL_01_06_1-37_01_3125.mzXML Peak area  \
# 0                                1.317142e+06
# 1                                1.256917e+06
# 2                                1.812014e+05
# 3                                6.051916e+05
# 4                                7.009724e+05
#
#    225_3uL_03_07_1-92_01_3787.mzXML Peak area  \
# 0                                1.292446e+06
# 1                                1.198393e+06
# 2                                3.515917e+04
# 3                                1.972567e+06
# 4                                4.861288e+05
#
#    226_3uL_03_07_1-6_01_3686.mzXML Peak area  Unnamed: 15
# 0                                  2443.4200          NaN
# 1                                   303.0000          NaN
# 2                                   338.3965          NaN
# 3                                     0.0000          NaN
# 4                                     0.0000          NaN

# %%
sample_metadata = gnps_result.meta
df = gnps_result.feat

sample_metadata.rename(index=str, columns={"filename": "#SampleID"},
                           inplace=True)
sample_metadata.columns = sample_metadata.columns.str.replace('\s', '_')

sample_metadata.index = sample_metadata['#SampleID']
sample_metadata.drop(['#SampleID'], axis=1, inplace=True)
qsample_metadata = qiime2.metadata.Metadata(sample_metadata)

df2 = df[df.columns[df.columns.str.contains(' Peak area')]]
df2.columns = [re.sub('(.+\.mzX?ML) .+', '\\1', a) for a in df2.columns]
df2.index = df['row ID'].astype(str)
df2 = df2.T
# Out:
# /tmp/ipykernel_1090/4162826805.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   sample_metadata.columns = sample_metadata.columns.str.replace('\s', '_')

# %%
df2.head()
# Out:
# row ID                                     5            7             8  \
# 12_3uL_30_05_1-68_01_3052.mzXML  1099282.475   999817.425  1.348523e+06
# 78_3uL_03_07_1-66_01_3757.mzXML  1631616.110  1445426.520  1.536206e+06
# 11_3uL_01_06_1-42_01_3131.mzXML  1281667.895  1249140.445  5.228738e+06
# 10_3uL_30_05_1-33_01_3004.mzXML   860049.175   915588.990  1.779064e+06
# 80_3uL_30_05_1-58_01_3033.mzXML  1254956.950  1234167.890  1.275157e+05
#
# row ID                                    10          13           15  \
# 12_3uL_30_05_1-68_01_3052.mzXML   550534.675  664308.600   872762.290
# 78_3uL_03_07_1-66_01_3757.mzXML  1259964.695  299720.325  1102765.640
# 11_3uL_01_06_1-42_01_3131.mzXML  1099087.450  812770.880   900354.130
# 10_3uL_30_05_1-33_01_3004.mzXML  1900706.545  559341.440   652475.155
# 80_3uL_30_05_1-58_01_3033.mzXML   525107.070  714114.810   919774.190
#
# row ID                                   16          17           19  \
# 12_3uL_30_05_1-68_01_3052.mzXML  394166.740  679873.427   380556.605
# 78_3uL_03_07_1-66_01_3757.mzXML  539348.905     606.372   839610.910
# 11_3uL_01_06_1-42_01_3131.mzXML  568145.865  449986.256   890581.265
# 10_3uL_30_05_1-33_01_3004.mzXML  841555.890  359513.092  1468203.685
# 80_3uL_30_05_1-58_01_3033.mzXML  252188.315     146.088   368269.425
#
# row ID                                     20  ...    3214     3236      3249  \
# 12_3uL_30_05_1-68_01_3052.mzXML  8.229792e+05  ...  307.53  137.700   886.780
# 78_3uL_03_07_1-66_01_3757.mzXML  1.195869e+06  ...  242.25  419.195  1802.900
# 11_3uL_01_06_1-42_01_3131.mzXML  9.003798e+05  ...  685.80   86.840   435.375
# 10_3uL_30_05_1-33_01_3004.mzXML  5.970800e+02  ...  448.80  408.880  2410.925
# 80_3uL_30_05_1-58_01_3033.mzXML  2.025829e+04  ...  374.85  110.670   131.070
#
# row ID                              3258  3276    3280      3309    3312  \
# 12_3uL_30_05_1-68_01_3052.mzXML  230.000   0.0   84.15   211.630  253.98
# 78_3uL_03_07_1-66_01_3757.mzXML    0.000   0.0  110.67  1571.560  233.07
# 11_3uL_01_06_1-42_01_3131.mzXML  198.940   0.0   71.40   651.780  358.02
# 10_3uL_30_05_1-33_01_3004.mzXML  177.030   0.0  100.37   390.660  292.23
# 80_3uL_30_05_1-58_01_3033.mzXML  135.355  86.7   98.94    43.645  422.56
#
# row ID                             3318    3357
# 12_3uL_30_05_1-68_01_3052.mzXML  176.13  138.72
# 78_3uL_03_07_1-66_01_3757.mzXML    0.00  252.45
# 11_3uL_01_06_1-42_01_3131.mzXML  328.90  260.10
# 10_3uL_30_05_1-33_01_3004.mzXML  151.47  493.29
# 80_3uL_30_05_1-58_01_3033.mzXML  655.20  171.00
#
# [5 rows x 486 columns]

# %%
# current version
# pqn
#        if self.normType == 'PQN':
#            medians = df.median(axis=1)
#            normalized_df = df.div(medians, axis=0)
#            normalized_df *= medians.median()
#            return normalized_df

# %%
# 12 samples 'n' samples on the paper
# 486 variables 'd' variables
df2.shape
# Out:
# (12, 486)

# %%
medians = df2.median(axis=1)
medians.shape
# Out:
# (12,)

# %%
# Example 3 samples, 4 variables
# Validate against other implementation
# https://rdrr.io/github/ricoderks/Rcpm/src/R/pqn.R
temp = pd.DataFrame([[2.0438199, -0.4881113,  0.7856725, -0.8118500],
                     [-0.7760712, -0.7189763, -0.9654193,  0.8786014],
                     [1.1694329, -0.4759941, -1.1107615, -2.1956906]])

temp.median()
# Out:
# 0    1.169433
# 1   -0.488111
# 2   -0.965419
# 3   -0.811850
# dtype: float64

# %%
temp.div(temp.median(), axis=1)
# Out:
#           0         1         2         3
# 0  1.747702  1.000000 -0.813815  1.000000
# 1 -0.663630  1.472976  1.000000 -1.082221
# 2  1.000000  0.975175  1.150548  2.704552

# %%
median_temp = temp.div(temp.median(), axis=1)
median_temp.median(axis=1)
# Out:
# 0    1.000000
# 1    0.168185
# 2    1.075274
# dtype: float64

# %%
temp.div(median_temp.median(axis=1), axis=0)
# Out:
#           0         1         2         3
# 0  2.043820 -0.488111  0.785672 -0.811850
# 1 -4.614395 -4.274918 -5.740229  5.224024
# 2  1.087567 -0.442672 -1.033003 -2.041982

# %%
temp[0]/median_temp.median(axis=1)
# Out:
# 0    2.043820
# 1   -4.614395
# 2    1.087567
# dtype: float64

# %%
df2.median().shape
# Out:
# (486,)

# %%
# TIC
normalized_df = df2.apply(lambda a: a/sum(a), axis=1)

normalized_df.head()
# Out:
# row ID                                  5         7         8        10  \
# 12_3uL_30_05_1-68_01_3052.mzXML  0.032602  0.029652  0.039994  0.016328
# 78_3uL_03_07_1-66_01_3757.mzXML  0.031309  0.027736  0.029478  0.024177
# 11_3uL_01_06_1-42_01_3131.mzXML  0.025865  0.025209  0.105520  0.022180
# 10_3uL_30_05_1-33_01_3004.mzXML  0.020314  0.021625  0.042020  0.044893
# 80_3uL_30_05_1-58_01_3033.mzXML  0.049144  0.048330  0.004994  0.020563
#
# row ID                                 13        15        16        17  \
# 12_3uL_30_05_1-68_01_3052.mzXML  0.019702  0.025884  0.011690  0.020164
# 78_3uL_03_07_1-66_01_3757.mzXML  0.005751  0.021161  0.010349  0.000012
# 11_3uL_01_06_1-42_01_3131.mzXML  0.016402  0.018170  0.011466  0.009081
# 10_3uL_30_05_1-33_01_3004.mzXML  0.013211  0.015411  0.019877  0.008491
# 80_3uL_30_05_1-58_01_3033.mzXML  0.027965  0.036018  0.009876  0.000006
#
# row ID                                 19        20  ...      3214      3236  \
# 12_3uL_30_05_1-68_01_3052.mzXML  0.011286  0.024408  ...  0.000009  0.000004
# 78_3uL_03_07_1-66_01_3757.mzXML  0.016111  0.022947  ...  0.000005  0.000008
# 11_3uL_01_06_1-42_01_3131.mzXML  0.017973  0.018170  ...  0.000014  0.000002
# 10_3uL_30_05_1-33_01_3004.mzXML  0.034678  0.000014  ...  0.000011  0.000010
# 80_3uL_30_05_1-58_01_3033.mzXML  0.014421  0.000793  ...  0.000015  0.000004
#
# row ID                               3249      3258      3276      3280  \
# 12_3uL_30_05_1-68_01_3052.mzXML  0.000026  0.000007  0.000000  0.000002
# 78_3uL_03_07_1-66_01_3757.mzXML  0.000035  0.000000  0.000000  0.000002
# 11_3uL_01_06_1-42_01_3131.mzXML  0.000009  0.000004  0.000000  0.000001
# 10_3uL_30_05_1-33_01_3004.mzXML  0.000057  0.000004  0.000000  0.000002
# 80_3uL_30_05_1-58_01_3033.mzXML  0.000005  0.000005  0.000003  0.000004
#
# row ID                               3309      3312      3318      3357
# 12_3uL_30_05_1-68_01_3052.mzXML  0.000006  0.000008  0.000005  0.000004
# 78_3uL_03_07_1-66_01_3757.mzXML  0.000030  0.000004  0.000000  0.000005
# 11_3uL_01_06_1-42_01_3131.mzXML  0.000013  0.000007  0.000007  0.000005
# 10_3uL_30_05_1-33_01_3004.mzXML  0.000009  0.000007  0.000004  0.000012
# 80_3uL_30_05_1-58_01_3033.mzXML  0.000002  0.000017  0.000026  0.000007
#
# [5 rows x 486 columns]

# %%
# All samples sum to 1
# sanity check is ok
normalized_df.sum(axis=1)
# Out:
# 12_3uL_30_05_1-68_01_3052.mzXML     1.0
# 78_3uL_03_07_1-66_01_3757.mzXML     1.0
# 11_3uL_01_06_1-42_01_3131.mzXML     1.0
# 10_3uL_30_05_1-33_01_3004.mzXML     1.0
# 80_3uL_30_05_1-58_01_3033.mzXML     1.0
# 153_3uL_01_06_1-23_01_3111.mzXML    1.0
# 152_3uL_01_06_1-87_01_3074.mzXML    1.0
# 79_3uL_03_07_1-17_01_3699.mzXML     1.0
# 224_3uL_03_07_1-81_01_3774.mzXML    1.0
# 154_3uL_01_06_1-37_01_3125.mzXML    1.0
# 225_3uL_03_07_1-92_01_3787.mzXML    1.0
# 226_3uL_03_07_1-6_01_3686.mzXML     1.0
# dtype: float64

# %%
# autoscaling
scaled_df = (df2 - df2.mean()) / (df2.std())

scaled_df.head()
# Out:
# row ID                                  5         7         8        10  \
# 12_3uL_30_05_1-68_01_3052.mzXML -0.058108 -0.161682  0.220540 -0.499475
# 78_3uL_03_07_1-66_01_3757.mzXML  1.213274  0.991748  0.343840  0.235148
# 11_3uL_01_06_1-42_01_3131.mzXML  0.377487  0.483674  2.769691  0.068558
# 10_3uL_30_05_1-33_01_3004.mzXML -0.629473 -0.379702  0.503389  0.898644
# 80_3uL_30_05_1-58_01_3033.mzXML  0.313692  0.444919 -0.581614 -0.525806
#
# row ID                                 13        15        16        17  \
# 12_3uL_30_05_1-68_01_3052.mzXML  0.460604  0.393378 -0.225378  1.827118
# 78_3uL_03_07_1-66_01_3757.mzXML -0.960693  0.891587 -0.000620 -0.881245
# 11_3uL_01_06_1-42_01_3131.mzXML  1.039364  0.453145  0.043961  0.910515
# 10_3uL_30_05_1-33_01_3004.mzXML  0.051404 -0.083784  0.467230  0.549782
# 80_3uL_30_05_1-58_01_3033.mzXML  0.654767  0.495210 -0.445177 -0.883081
#
# row ID                                 19        20  ...      3214      3236  \
# 12_3uL_30_05_1-68_01_3052.mzXML -0.545206  1.107543  ... -0.293174 -0.300454
# 78_3uL_03_07_1-66_01_3757.mzXML  0.286357  1.975880  ... -0.298476 -0.282331
# 11_3uL_01_06_1-42_01_3131.mzXML  0.378688  1.287783  ... -0.262450 -0.303729
# 10_3uL_30_05_1-33_01_3004.mzXML  1.425033 -0.807513  ... -0.281700 -0.282995
# 80_3uL_30_05_1-58_01_3033.mzXML -0.567464 -0.761728  ... -0.287706 -0.302194
#
# row ID                               3249      3258      3276      3280  \
# 12_3uL_30_05_1-68_01_3052.mzXML -0.277118 -0.274021 -0.289398 -0.295142
# 78_3uL_03_07_1-66_01_3757.mzXML -0.156367 -0.299377 -0.289398 -0.292006
# 11_3uL_01_06_1-42_01_3131.mzXML -0.336617 -0.277446 -0.289398 -0.296649
# 10_3uL_30_05_1-33_01_3004.mzXML -0.076226 -0.279861 -0.289398 -0.293224
# 80_3uL_30_05_1-58_01_3033.mzXML -0.376726 -0.284455 -0.281442 -0.293393
#
# row ID                               3309      3312      3318      3357
# 12_3uL_30_05_1-68_01_3052.mzXML -0.366368 -0.313085 -0.287240 -0.312889
# 78_3uL_03_07_1-66_01_3757.mzXML -0.200487 -0.315952 -0.311415 -0.298702
# 11_3uL_01_06_1-42_01_3131.mzXML -0.312680 -0.298823 -0.266270 -0.297748
# 10_3uL_30_05_1-33_01_3004.mzXML -0.344531 -0.307842 -0.290624 -0.268660
# 80_3uL_30_05_1-58_01_3033.mzXML -0.386859 -0.289975 -0.221482 -0.308862
#
# [5 rows x 486 columns]

# %%
# mean scaled ~ 0 for all variables
# check ok
scaled_df.mean()
# Out:
# row ID
# 5       2.220446e-16
# 7       2.590520e-16
# 8       1.850372e-17
# 10      1.665335e-16
# 13      2.960595e-16
#             ...
# 3280   -3.700743e-17
# 3309   -7.401487e-17
# 3312   -3.700743e-17
# 3318    0.000000e+00
# 3357    3.700743e-17
# Length: 486, dtype: float64

# %%
# std ~ 1 for all variables
# check ok
scaled_df.std()
# Out:
# row ID
# 5       1.0
# 7       1.0
# 8       1.0
# 10      1.0
# 13      1.0
#        ...
# 3280    1.0
# 3309    1.0
# 3312    1.0
# 3318    1.0
# 3357    1.0
# Length: 486, dtype: float64
